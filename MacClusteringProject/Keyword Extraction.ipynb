# %%
import pandas as pd
from rake_nltk import Rake

# %%
incidents = pd.read_excel('incidents_with_problems.xlsx')

# %% [markdown]
# ### Show example of keyword extraction

# %%
# incidents = incidents.dropna(axis=1)
incidents.iloc[0]['Description']
# Out:
# "<EXECUTIVE NOTIFY: FEDEX-SEV4>\n06/17/18 01:04 MOC / GOC and PIT Phone Turret Phone issue INCIDENT START MOC (Maintenance Operation Center), GOC (Global Operations Center) and PITT users are experiencing issues with their new Turret phones. The issue is impacting PIT customers ability to place orders and GOC's ability to place or receive calls out of the Control Center. Per MOC some ACARS dependencies will are being impacted as well. VOIP support teams have been working to resolve the issue and a high level case has been opened with CISCO-TAC. The issue began at 22:00 CDT. The IT Command Center was informed at 22:46 CDT.\n"

# %%
r = Rake(min_length=2, max_length=8)
keywords = r.extract_keywords_from_text(incidents.iloc[0]['Description'])
# incidents.iloc[0]['Description']

# %%
r.get_ranked_phrases()
# Out:
# ['pit phone turret phone issue incident start moc',
#  'maintenance operation center ), goc',
#  'impacting pit customers ability',
#  'new turret phones',
#  'voip support teams',
#  'high level case',
#  'global operations center',
#  'issue began',
#  'per moc',
#  '04 moc',
#  'control center',
#  'command center',
#  'receive calls',
#  'place orders',
#  'pitt users',
#  'experiencing issues',
#  'executive notify',
#  'acars dependencies',
#  '46 cdt',
#  '18 01',
#  '00 cdt']

# %% [markdown]
# #### Define function to map Description feature to Keywords
# After some playing around, min_length 2 and max_length 8 for the keyword phrases seemed to work the best with the Descriptions in the dataset.
# I also chose to make a list of the top 4 keyword phrases because many of the ranked phrases did not have a desirable phrase as the first item, but most from what I saw did by the 4th item.
# These both may need to be adjusted later and there are other parameters such as using different stop word dictionaries that can be tweaked later.

# %%
def extract_keywords(text):
    r = Rake(min_length=2, max_length=8)
    r.extract_keywords_from_text(text)
    return r.get_ranked_phrases()[0:4]

# %% [markdown]
# ### Add Keywords feature extracting from Description

# %%
incidents.insert(loc=2, column='Keywords', value=incidents['Description'].apply(extract_keywords))

# desc_data = full_data[['Number', 'Description']]
# desc_data.columns = desc_data.columns.str.replace('Problem', 'Number')
incidents
# Out:
#             Number     Problem  \
# 0     INC010068680  PRB0060003
# 1     INC010000197  PRB0060003
# 2     INC010003952  PRB0060019
# 3     INC010269074  PRB0060026
# 4     INC010269078  PRB0060026
# 5     INC010269072  PRB0060026
# 6     INC010269075  PRB0060026
# 7     INC010269077  PRB0060026
# 8     INC010217816  PRB0060026
# 9     INC010088825  PRB0060026
# 10    INC010007808  PRB0060026
# 11    INC010064126  PRB0060026
# 12    INC010049825  PRB0060026
# 13    INC010265588  PRB0060026
# 14    INC010174760  PRB0060026
# 15    INC010269073  PRB0060026
# 16    INC010004972  PRB0060029
# 17    INC010002999  PRB0060030
# 18    INC010012337  PRB0060037
# 19    INC010013439  PRB0060038
# 20    INC010012416  PRB0060040
# 21    INC010007775  PRB0060041
# 22    INC010009302  PRB0060042
# 23    INC010009858  PRB0060044
# 24    INC010016518  PRB0060045
# 25    INC010018413  PRB0060048
# 26    INC010016149  PRB0060050
# 27    INC010017788  PRB0060053
# 28    INC010021797  PRB0060054
# 29    INC010019190  PRB0060058
# ...            ...         ...
# 979   INC011275014  PRB0063355
# 980   INC011278159  PRB0063357
# 981   INC011276142  PRB0063359
# 982   INC011279336  PRB0063360
# 983   INC011280285  PRB0063361
# 984   INC011279439  PRB0063362
# 985   INC011280791  PRB0063363
# 986   INC011281250  PRB0063364
# 987   INC011281653  PRB0063365
# 988   INC011281608  PRB0063366
# 989   INC011282115  PRB0063369
# 990   INC011290628  PRB0063380
# 991   INC011292733  PRB0063381
# 992   INC011294220  PRB0063382
# 993   INC011295757  PRB0063397
# 994   INC011297807  PRB0063400
# 995   INC011298518  PRB0063401
# 996   INC011303020  PRB0063405
# 997   INC011304472  PRB0063406
# 998   INC011304411  PRB0063419
# 999   INC011305140  PRB0063420
# 1000  INC011303349  PRB0063432
# 1001  INC011309598  PRB0063433
# 1002  INC011310292  PRB0063434
# 1003  INC011311884  PRB0063435
# 1004  INC011313908  PRB0063440
# 1005  INC011318116  PRB0063444
# 1006  INC011320061  PRB0063445
# 1007  INC011317625  PRB0063446
# 1008  INC011321774  PRB0063447
#
#                                                Keywords  Active  \
# 0     [pit phone turret phone issue incident start m...   False
# 1     [pit phone turret phone issue incident start m...   False
# 2     [multiple locations reporting user login issue...   False
# 3     [multiple customer service systems including c...   False
# 4     [multiple customer service systems including c...   False
# 5     [multiple customer service systems including c...   False
# 6     [multiple customer service systems including c...   False
# 7     [multiple customer service systems including c...   False
# 8     [multiple customer service systems including c...   False
# 9     [multiple customer service systems including c...   False
# 10    [multiple customer service systems including c...   False
# 11    [multiple customer service systems including c...   False
# 12    [multiple customer service systems including c...   False
# 13    [multiple customer service systems including c...   False
# 14    [multiple customer service systems including c...   False
# 15    [multiple customer service systems including c...   False
# 16    [com automic_scheduler forward_pgh jobstatus a...   False
# 17    [brokers cannot perform clearance activities w...   False
# 18    [19 pittsburg call center incident end, 46 pit...   False
# 19    [18 enterprise service desk chat incident end,...   False
# 20    [see connection failures due, outage due, supp...   False
# 21    [44 fxg shpt 0711 bandwidth issue end, site ex...   False
# 22                        [session 3 times, could kill]   False
# 23    [applications like epdsm running slow, 25 pm j...   False
# 24    [vdi slowness hi ms, fedex service desk locate...   False
# 25    [goc universal resource utility ), workbench, ...   False
# 26    [issue cleared without intervention, webservic...   False
# 27    [04 fedexnet issue incident start fedexnet web...   False
# 28    [two backend servers, common rate services, se...   False
# 29    [fedex ground publishing application, running ...   False
# ...                                                 ...     ...
# 979   [com automic_scheduler forward_cos jobstatus a...   False
# 980        [com 503 errors, inc011272638 )., aem issue]    True
# 981   [dba team reconfigured stored gccs processes, ...   False
# 982   [general slowness due, eprs users, database is...   False
# 983   [retail clients experienced issues accessing f...   False
# 984   [mem call center, little longer, info manually...   False
# 985   [multiple ground users, business objects due, ...   False
# 986   [airwatch application wiping, airwatch support...   False
# 987   [issue cleared without intervention, fxo print...   False
# 988   [issue resolved without intervention, apac exp...   False
# 989   [7650 gr packages inbound sort 200 packages, m...   False
# 990   [splunk reported crs errors affecting cshp, is...   False
# 991   [global dispatch program, dispatch work statio...   False
# 992   [hub operations summary website, https :// ess...   False
# 993   [purchase fedex shipping services, fedex shipp...   False
# 994   [freight field sort support edited, thor forkl...   False
# 995   [chewy boxes phone number, chewy boxes user, u...   False
# 996   [payroll department experienced issues process...   False
# 997   [fedex ground station 490, sort operations, po...   False
# 998                 [rootcause ip availability failure]   False
# 999   [use manual sort procedures, performing inboun...   False
# 1000  [experienced network connectivity issues due, ...   False
# 1001  [fxo development team noticed, tax service ser...   False
# 1002  [smartpost ground site 5893, experienced utili...   False
# 1003  [global fedex billing online, united kingdom, ...    True
# 1004  [get proper options upon enrollment, support t...    True
# 1005  [10 minute delay, reporting blank manifest, mu...    True
# 1006  [experiencing sporadic timeouts, experienced s...    True
# 1007  [experiencing issues opening traces correctly ...   False
# 1008  [process invoices, issue began, firewall suppo...    True
#
#             Activity due  Additional assignee list           Approval  \
# 0                    NaT                       NaN  Not Yet Requested
# 1                    NaT                       NaN  Not Yet Requested
# 2                    NaT                       NaN  Not Yet Requested
# 3                    NaT                       NaN  Not Yet Requested
# 4                    NaT                       NaN  Not Yet Requested
# 5                    NaT                       NaN  Not Yet Requested
# 6                    NaT                       NaN  Not Yet Requested
# 7                    NaT                       NaN  Not Yet Requested
# 8                    NaT                       NaN  Not Yet Requested
# 9                    NaT                       NaN  Not Yet Requested
# 10                   NaT                       NaN  Not Yet Requested
# 11                   NaT                       NaN  Not Yet Requested
# 12                   NaT                       NaN  Not Yet Requested
# 13                   NaT                       NaN  Not Yet Requested
# 14                   NaT                       NaN  Not Yet Requested
# 15                   NaT                       NaN  Not Yet Requested
# 16                   NaT                       NaN  Not Yet Requested
# 17                   NaT                       NaN  Not Yet Requested
# 18                   NaT                       NaN  Not Yet Requested
# 19                   NaT                       NaN  Not Yet Requested
# 20                   NaT                       NaN  Not Yet Requested
# 21                   NaT                       NaN  Not Yet Requested
# 22                   NaT                       NaN  Not Yet Requested
# 23                   NaT                       NaN  Not Yet Requested
# 24                   NaT                       NaN  Not Yet Requested
# 25                   NaT                       NaN  Not Yet Requested
# 26                   NaT                       NaN  Not Yet Requested
# 27                   NaT                       NaN  Not Yet Requested
# 28                   NaT                       NaN  Not Yet Requested
# 29                   NaT                       NaN  Not Yet Requested
# ...                  ...                       ...                ...
# 979                  NaT                       NaN  Not Yet Requested
# 980                  NaT                       NaN  Not Yet Requested
# 981                  NaT                       NaN  Not Yet Requested
# 982                  NaT                       NaN  Not Yet Requested
# 983                  NaT                       NaN  Not Yet Requested
# 984                  NaT                       NaN  Not Yet Requested
# 985                  NaT                       NaN  Not Yet Requested
# 986                  NaT                       NaN  Not Yet Requested
# 987                  NaT                       NaN  Not Yet Requested
# 988                  NaT                       NaN  Not Yet Requested
# 989                  NaT                       NaN  Not Yet Requested
# 990                  NaT                       NaN  Not Yet Requested
# 991                  NaT                       NaN  Not Yet Requested
# 992                  NaT                       NaN  Not Yet Requested
# 993                  NaT                       NaN  Not Yet Requested
# 994                  NaT                       NaN  Not Yet Requested
# 995                  NaT                       NaN  Not Yet Requested
# 996  2019-02-25 19:39:56                       NaN  Not Yet Requested
# 997                  NaT                       NaN  Not Yet Requested
# 998                  NaT                       NaN  Not Yet Requested
# 999                  NaT                       NaN  Not Yet Requested
# 1000                 NaT                       NaN  Not Yet Requested
# 1001                 NaT                       NaN  Not Yet Requested
# 1002                 NaT                       NaN  Not Yet Requested
# 1003                 NaT                       NaN  Not Yet Requested
# 1004                 NaT                       NaN  Not Yet Requested
# 1005                 NaT                       NaN  Not Yet Requested
# 1006                 NaT                       NaN  Not Yet Requested
# 1007                 NaT                       NaN  Not Yet Requested
# 1008                 NaT                       NaN  Not Yet Requested
#
#       Approval history  Approval set              Assigned to  \
# 0                  NaN           NaN                      NaN
# 1                  NaN           NaN              Kevin Moore
# 2                  NaN           NaN             Kevin Mathis
# 3                  NaN           NaN         Rochelle Coleman
# 4                  NaN           NaN         Rochelle Coleman
# 5                  NaN           NaN         Rochelle Coleman
# 6                  NaN           NaN         Rochelle Coleman
# 7                  NaN           NaN         Rochelle Coleman
# 8                  NaN           NaN         Rochelle Coleman
# 9                  NaN           NaN         Rochelle Coleman
# 10                 NaN           NaN         Rochelle Coleman
# 11                 NaN           NaN         Rochelle Coleman
# 12                 NaN           NaN         Rochelle Coleman
# 13                 NaN           NaN         Rochelle Coleman
# 14                 NaN           NaN         Rochelle Coleman
# 15                 NaN           NaN         Rochelle Coleman
# 16                 NaN           NaN         Nitin Kumar Rana
# 17                 NaN           NaN      Soumya Ranjan Swain
# 18                 NaN           NaN              Todd Ritter
# 19                 NaN           NaN             Junior Opela
# 20                 NaN           NaN              Robbie Pike
# 21                 NaN           NaN               Janis Paul
# 22                 NaN           NaN              Robert Wood
# 23                 NaN           NaN              James Capps
# 24                 NaN           NaN              James Capps
# 25                 NaN           NaN             James Turner
# 26                 NaN           NaN             Sheila Swain
# 27                 NaN           NaN            Teresa Harper
# 28                 NaN           NaN         Brittany Shaffer
# 29                 NaN           NaN             Anthony Cole
# ...                ...           ...                      ...
# 979                NaN           NaN        Aniruddha Tumalla
# 980                NaN           NaN           Brian Hastings
# 981                NaN           NaN               Sophie Yin
# 982                NaN           NaN         Brittany Shaffer
# 983                NaN           NaN             Bradley Odom
# 984                NaN           NaN            Kenneth Boyce
# 985                NaN           NaN           Mark Kozlowski
# 986                NaN           NaN              Michael Wee
# 987                NaN           NaN        Christopher Longo
# 988                NaN           NaN             Andrew Bacon
# 989                NaN           NaN     Ramakrishnan Ganesan
# 990                NaN           NaN             Ryan Ridgway
# 991                NaN           NaN              David Smith
# 992                NaN           NaN            Michael Suess
# 993                NaN           NaN              Steven Byrd
# 994                NaN           NaN            Donald Rogers
# 995                NaN           NaN            Mounika Reddy
# 996                NaN           NaN          Jason Goldfeder
# 997                NaN           NaN                M. Dinesh
# 998                NaN           NaN                M. Dinesh
# 999                NaN           NaN          Steven Kregness
# 1000               NaN           NaN              Rajaguru C.
# 1001               NaN           NaN   Pragathi Narayanaswamy
# 1002               NaN           NaN              Rajaguru C.
# 1003               NaN           NaN  Nagaraju Chinnakachenna
# 1004               NaN           NaN         Purnakumar Thota
# 1005               NaN           NaN        Timothy Wilkerson
# 1006               NaN           NaN             Dustin Henry
# 1007               NaN           NaN         Donald Gualtieri
# 1008               NaN           NaN           D'Zundra Green
#
#             ...        Awareness (Min)  CHECKOUT (MIN) ESCALATION (MIN)  \
# 0           ...                    NaN             NaN              NaN
# 1           ...                   66.0             0.0              0.0
# 2           ...                    1.0             0.0             60.0
# 3           ...                    NaN             NaN              NaN
# 4           ...                    NaN             NaN              NaN
# 5           ...                    NaN             NaN              NaN
# 6           ...                    NaN             NaN              NaN
# 7           ...                    NaN             NaN              NaN
# 8           ...                    NaN             NaN              NaN
# 9           ...                    NaN             NaN              NaN
# 10          ...                   14.0            29.0             11.0
# 11          ...                    NaN             NaN              NaN
# 12          ...                    NaN             NaN              NaN
# 13          ...                    NaN             NaN              NaN
# 14          ...                    NaN             NaN              NaN
# 15          ...                    NaN             NaN              NaN
# 16          ...                    NaN             NaN              NaN
# 17          ...                    NaN             NaN              NaN
# 18          ...                    1.0          2674.0             29.0
# 19          ...                    0.0             0.0              0.0
# 20          ...                   12.0             0.0              3.0
# 21          ...                  435.0             0.0              0.0
# 22          ...                    6.0             0.0              0.0
# 23          ...                    NaN             NaN              NaN
# 24          ...                    NaN             NaN              NaN
# 25          ...                   12.0             0.0              7.0
# 26          ...                    0.0             0.0              0.0
# 27          ...                   11.0             0.0              8.0
# 28          ...                    6.0             0.0              5.0
# 29          ...                   30.0             0.0              0.0
# ...         ...                    ...             ...              ...
# 979         ...                   36.0            13.0              4.0
# 980         ...                    NaN             NaN              NaN
# 981         ...                    2.0             7.0              0.0
# 982         ...                    2.0            10.0              2.0
# 983         ...                    0.0            86.0              2.0
# 984         ...                    8.0             4.0            151.0
# 985         ...                    7.0             6.0              2.0
# 986         ...                   11.0            65.0              1.0
# 987         ...                    2.0            14.0              2.0
# 988         ...                    5.0            17.0              0.0
# 989         ...                    0.0             0.0              0.0
# 990         ...                    1.0            14.0              3.0
# 991         ...                   11.0            12.0              0.0
# 992         ...                    2.0            12.0             62.0
# 993         ...                    1.0             0.0              1.0
# 994         ...                   10.0            33.0              0.0
# 995         ...                  145.0            20.0             59.0
# 996         ...                   35.0            61.0             20.0
# 997         ...                    0.0             2.0              0.0
# 998         ...                    NaN             NaN              NaN
# 999         ...                    0.0             5.0              0.0
# 1000        ...                    1.0            14.0              1.0
# 1001        ...                    1.0            13.0              0.0
# 1002        ...                    0.0             0.0              1.0
# 1003        ...                    3.0            10.0              2.0
# 1004        ...                    2.0             1.0             15.0
# 1005        ...                   20.0            72.0             12.0
# 1006        ...                    8.0             2.0              0.0
# 1007        ...                   14.0           200.0              1.0
# 1008        ...                    0.0             5.0              0.0
#
#       REMEDIATION (MIN)  TIMELINE DURATION (MIN) TRIAGE (MIN)  \
# 0                   NaN                      NaN          NaN
# 1                  14.0                    362.0        282.0
# 2                   0.0                    101.0         40.0
# 3                   NaN                      NaN          NaN
# 4                   NaN                      NaN          NaN
# 5                   NaN                      NaN          NaN
# 6                   NaN                      NaN          NaN
# 7                   NaN                      NaN          NaN
# 8                   NaN                      NaN          NaN
# 9                   NaN                      NaN          NaN
# 10                 24.0                     83.0         22.0
# 11                  NaN                      NaN          NaN
# 12                  NaN                      NaN          NaN
# 13                  NaN                      NaN          NaN
# 14                  NaN                      NaN          NaN
# 15                  NaN                      NaN          NaN
# 16                  NaN                      NaN          NaN
# 17                  NaN                      NaN          NaN
# 18                 12.0                     57.0          3.0
# 19                 10.0                     70.0         60.0
# 20                125.0                    150.0          5.0
# 21                  5.0                    450.0         10.0
# 22                 10.0                    365.0         45.0
# 23                  NaN                      NaN          NaN
# 24                  NaN                      NaN          NaN
# 25                  0.0                     80.0         43.0
# 26                  9.0                      9.0          0.0
# 27                 66.0                    208.0        111.0
# 28                  4.0                     47.0         31.0
# 29               1320.0                   2017.0        635.0
# ...                 ...                      ...          ...
# 979                 4.0                    740.0        694.0
# 980                 NaN                      NaN          NaN
# 981                50.0                   1207.0        194.0
# 982                 0.0                    105.0          1.0
# 983                 4.0                      6.0          0.0
# 984                 0.0                    300.0        140.0
# 985                 9.0                     61.0         18.0
# 986                 2.0                    192.0          1.0
# 987                 0.0                     75.0         36.0
# 988                 0.0                     65.0         57.0
# 989               290.0                    501.0         50.0
# 990                 0.0                      5.0          1.0
# 991                 0.0                     94.0         18.0
# 992                 9.0                    150.0          0.0
# 993                85.0                     97.0          5.0
# 994                35.0                    236.0         30.0
# 995                45.0                    285.0         36.0
# 996                 4.0                    124.0         60.0
# 997                20.0                     53.0          0.0
# 998                 NaN                      NaN          NaN
# 999                18.0                     75.0         22.0
# 1000                0.0                    360.0        332.0
# 1001                6.0                     90.0         63.0
# 1002              231.0                    280.0          0.0
# 1003               50.0                   2030.0        450.0
# 1004                2.0                    881.0         15.0
# 1005               15.0                    285.0        228.0
# 1006                3.0                     99.0         72.0
# 1007               52.0                    592.0        369.0
# 1008                0.0                    198.0        182.0
#
#      Acknowledge (Min) BSD call     New Call  Vendor Exception
# 0                  NaN      NaN          NaN               NaN
# 1                 66.0      NaN          NaN               NaN
# 2                  1.0      NaN          NaN               NaN
# 3                  NaN      NaN          NaN               NaN
# 4                  NaN      NaN          NaN               NaN
# 5                  NaN      NaN          NaN               NaN
# 6                  NaN      NaN          NaN               NaN
# 7                  NaN      NaN          NaN               NaN
# 8                  NaN      NaN          NaN               NaN
# 9                  NaN      NaN          NaN               NaN
# 10                26.0      NaN          NaN               NaN
# 11                 NaN      NaN          NaN               NaN
# 12                 NaN      NaN          NaN               NaN
# 13                 NaN      NaN          NaN               NaN
# 14                 NaN      NaN          NaN               NaN
# 15                 NaN      NaN          NaN               NaN
# 16                 NaN      NaN          NaN               NaN
# 17                 NaN      NaN          NaN               NaN
# 18                13.0      NaN          NaN               NaN
# 19                 0.0      NaN          NaN               NaN
# 20                17.0      NaN          NaN               NaN
# 21               435.0      NaN          NaN               NaN
# 22               310.0      NaN          NaN               NaN
# 23                 NaN      NaN          NaN               NaN
# 24                 NaN      NaN          NaN               NaN
# 25                30.0      NaN          NaN               NaN
# 26                 0.0      NaN          NaN               NaN
# 27                23.0      NaN          NaN               NaN
# 28                 7.0      NaN          NaN               NaN
# 29                62.0      NaN          NaN               NaN
# ...                ...      ...          ...               ...
# 979               38.0      NaN          NaN               NaN
# 980                NaN      NaN          NaN               NaN
# 981              962.0      NaN          NaN               NaN
# 982              102.0      NaN          NaN               NaN
# 983                0.0      NaN          NaN               NaN
# 984                9.0      NaN          NaN               NaN
# 985               32.0      NaN          NaN               NaN
# 986              188.0      NaN          NaN               NaN
# 987               37.0      NaN          NaN               NaN
# 988                8.0      NaN          NaN               NaN
# 989              161.0      NaN  CALL0418278               NaN
# 990                1.0      NaN          NaN               NaN
# 991               76.0      NaN          NaN               NaN
# 992               79.0      NaN          NaN               NaN
# 993                6.0      NaN          NaN               NaN
# 994              171.0      NaN  CALL0424974               NaN
# 995              145.0      NaN  CALL0424967               NaN
# 996               40.0      NaN          NaN               NaN
# 997               33.0      NaN          NaN               NaN
# 998                NaN      NaN          NaN               NaN
# 999               35.0      NaN          NaN               NaN
# 1000              27.0      NaN          NaN               NaN
# 1001              21.0      NaN          NaN               NaN
# 1002              48.0      NaN          NaN               NaN
# 1003            1528.0      NaN          NaN               NaN
# 1004             850.0      NaN          NaN               NaN
# 1005              30.0      NaN          NaN               NaN
# 1006              25.0      NaN          NaN               NaN
# 1007             170.0      NaN          NaN               NaN
# 1008              16.0      NaN          NaN               NaN
#
# [1009 rows x 171 columns]
