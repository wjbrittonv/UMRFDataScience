# %%
import pandas as pd
from rake_nltk import Rake

# %%
incidents = pd.read_excel('incidents_2019-03-21.xlsx')

# %% [markdown]
# ### Show example of keyword extraction

# %%
# incidents = incidents.dropna(axis=1)
incidents.iloc[0]['Description']
# Out:
# "<EXECUTIVE NOTIFY: FEDEX-SEV4>\n06/17/18 01:04 MOC / GOC and PIT Phone Turret Phone issue INCIDENT START MOC (Maintenance Operation Center), GOC (Global Operations Center) and PITT users are experiencing issues with their new Turret phones. The issue is impacting PIT customers ability to place orders and GOC's ability to place or receive calls out of the Control Center. Per MOC some ACARS dependencies will are being impacted as well. VOIP support teams have been working to resolve the issue and a high level case has been opened with CISCO-TAC. The issue began at 22:00 CDT. The IT Command Center was informed at 22:46 CDT.\n"

# %%
r = Rake(min_length=2, max_length=8)
keywords = r.extract_keywords_from_text(incidents.iloc[0]['Description'])
# incidents.iloc[0]['Description']

# %%
r.get_ranked_phrases()
# Out:
# ['pit phone turret phone issue incident start moc',
#  'maintenance operation center ), goc',
#  'impacting pit customers ability',
#  'new turret phones',
#  'voip support teams',
#  'high level case',
#  'global operations center',
#  'issue began',
#  'per moc',
#  '04 moc',
#  'control center',
#  'command center',
#  'receive calls',
#  'place orders',
#  'pitt users',
#  'experiencing issues',
#  'executive notify',
#  'acars dependencies',
#  '46 cdt',
#  '18 01',
#  '00 cdt']

# %% [markdown]
# #### Define function to map Description feature to Keywords
# After some playing around, min_length 2 and max_length 8 for the keyword phrases seemed to work the best with the Descriptions in the dataset.
# I also chose to make a list of the top 4 keyword phrases because many of the ranked phrases did not have a desirable phrase as the first item, but most from what I saw did by the 4th item.
# These both may need to be adjusted later and there are other parameters such as using different stop word dictionaries that can be tweaked later.

# %%
def extract_keywords(text):
    r = Rake(min_length=2, max_length=8)
    r.extract_keywords_from_text(text)
    return r.get_ranked_phrases()[0:4]

# %% [markdown]
# ### Add Keywords feature extracting from Description

# %%
incidents.insert(loc=2, column='Keywords', value=incidents['Description'].apply(extract_keywords))

# desc_data = full_data[['Number', 'Description']]
# desc_data.columns = desc_data.columns.str.replace('Problem', 'Number')
incidents.head()
# Out:
#          Number     Problem  \
# 0  INC010068680  PRB0060003
# 1  INC010000197  PRB0060003
# 2  INC010003952  PRB0060019
# 3  INC010269074  PRB0060026
# 4  INC010269078  PRB0060026
#
#                                             Keywords Affected Company  \
# 0  [pit phone turret phone issue incident start m...    FedEx Express
# 1  [pit phone turret phone issue incident start m...    FedEx Express
# 2  [multiple locations reporting user login issue...   FedEx Services
# 3  [multiple customer service systems including c...   FedEx Services
# 4  [multiple customer service systems including c...   FedEx Services
#
#        Business service  ALERTING (MIN)  Awareness (Min)  Acknowledge (Min)  \
# 0  Communication Device             NaN              NaN                NaN
# 1  Communication Device             0.0             66.0               66.0
# 2               Scanner             0.0              1.0                1.0
# 3              Database             NaN              NaN                NaN
# 4              Database             NaN              NaN                NaN
#
#                Opened             Created       ...        User Location  \
# 0 2018-06-17 03:59:28 2018-06-28 00:53:59       ...                  NaN
# 1 2018-06-17 03:59:28 2018-06-17 04:04:04       ...                  NaN
# 2 2018-06-18 08:24:50 2018-06-18 08:41:13       ...                  NaN
# 3 2018-06-18 15:40:15 2018-07-31 16:55:15       ...                  NaN
# 4 2018-06-18 15:40:15 2018-07-31 16:55:19       ...                  NaN
#
#   User Network  User input VZ Correlation ID Vendor Exception  \
# 0          NaN         NaN               NaN              NaN
# 1          NaN         NaN               NaN              NaN
# 2          NaN         NaN               NaN              NaN
# 3          NaN         NaN               NaN              NaN
# 4          NaN         NaN               NaN              NaN
#
#   Vendor Incident Number Vendor Name Watch list  \
# 0                    NaN         NaN        NaN
# 1                    NaN         NaN        NaN
# 2                    NaN         NaN        NaN
# 3                    NaN         NaN        NaN
# 4                    NaN         NaN        NaN
#
#                                           Work notes  Work notes list
# 0                                                NaN              NaN
# 1  2018-08-02 13:32:12 - Stephen Barch (Work note...              NaN
# 2  2018-06-18 09:23:54 - Brad Moore (Work notes)\...              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
# [5 rows x 172 columns]

# %%
num_problems = incidents[['Number', 'Problem']]

# %%
prob_count = num_problems['Problem'].value_counts()
num_problems = num_problems[num_problems['Problem'].isin(prob_count[prob_count > 1].index)]
num_problems['Problem'].value_counts()
# Out:
# PRB0060187    24
# PRB0062159    15
# PRB0060026    13
# PRB0060758    10
# PRB0060146    10
# PRB0060985     9
# PRB0060120     9
# PRB0060147     6
# PRB0062412     5
# PRB0060990     5
# PRB0061073     4
# PRB0061956     4
# PRB0062104     4
# PRB0062432     4
# PRB0062207     4
# PRB0062358     4
# PRB0061373     4
# PRB0060194     4
# PRB0062384     4
# PRB0062320     4
# PRB0060188     3
# PRB0061448     3
# PRB0061283     3
# PRB0060718     3
# PRB0060075     3
# PRB0061315     3
# PRB0062186     3
# PRB0063084     3
# PRB0062329     3
# PRB0062222     3
#               ..
# PRB0061590     2
# PRB0062744     2
# PRB0061386     2
# PRB0061163     2
# PRB0061539     2
# PRB0062125     2
# PRB0060414     2
# PRB0061547     2
# PRB0061774     2
# PRB0061387     2
# PRB0062011     2
# PRB0061454     2
# PRB0063184     2
# PRB0062901     2
# PRB0061856     2
# PRB0060251     2
# PRB0062467     2
# PRB0061853     2
# PRB0061940     2
# PRB0061450     2
# PRB0061593     2
# PRB0061988     2
# PRB0061460     2
# PRB0061453     2
# PRB0061270     2
# PRB0060003     2
# PRB0062590     2
# PRB0061035     2
# PRB0061349     2
# PRB0062050     2
# Name: Problem, Length: 92, dtype: int64
