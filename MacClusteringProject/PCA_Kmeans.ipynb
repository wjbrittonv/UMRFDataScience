# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, ShuffleSplit, cross_validate,cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics, svm
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn import tree
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from scipy.stats import chisquare
import seaborn
from matplotlib import pyplot
import matplotlib.pyplot as plt
from matplotlib import rcParams
from sklearn.cluster import KMeans, DBSCAN
from sklearn.feature_selection import chi2, SelectKBest, SelectFdr
from sklearn.decomposition import PCA
from rake_nltk import Rake

# %%
df = pd.read_csv('problems_2categories_atprobcreation.csv')
X = df.drop('Category', axis=1).values
X
le = preprocessing.LabelEncoder()
for col in range(len(X[0])):
    X[:,col] = le.fit_transform(X[:,col])
# X = df.drop('Category', axis=1)
# X = pd.get_dummies(X, columns=["'Assignment group'", "'Business service'",
#                                'Company', "'Created Time'", "'Created by'", 
#                                "'Opened by'", 'Type'])
y = df['Category'].values
y
# Out:
# array(['Application', 'Application', 'Application', ..., 'Hardware',
#        'Hardware', 'Hardware'], dtype=object)

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import *
from matplotlib import pyplot
from sklearn.metrics import adjusted_rand_score, silhouette_score

pca = PCA(n_components=4)

# features = df[ ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'] ]
Xfit = pca.fit_transform(X)
df['pca1'] = Xfit[ : , 0]
df['pca2'] = Xfit[ : , 1]
df['pca3'] = Xfit[ : , 2]
df['pca4'] = Xfit[ : , 3]

model = KMeans(n_clusters=2)
model.fit(df[['pca1', 'pca2', 'pca3', 'pca4']])
print('Adjusted_Rand:', adjusted_rand_score(model.labels_, df.Category))
print('Silhouette:', silhouette_score(X, model.labels_))
print('Total explained variance:', sum(pca.explained_variance_ratio_))
seaborn.relplot(x='pca1', y='pca2', hue='Category', data = df)
fig = pyplot.figure()
ax = fig.add_subplot(111, projection='3d')

x = df['pca1']
y = df['pca2']
z = df['pca3']


for name, group in df.groupby('Category'):
    ax.scatter(group.pca1, group.pca2, group.pca3, label=name)
    
pyplot.show()
# Out:
# Adjusted_Rand: 0.0187079043115019
# Silhouette: 0.4973850734956272
# Total explained variance: 0.940712274316719

# %%
print(model.labels_)
# Out:
# [1 0 1 ... 0 0 0]

# %%
df
# Out:
#                'Assignment group'      'Business service'     Category  \
# 0       FXO_SDESK_GLB_ProblemMgmt                Computer  Application
# 1                           Other                  Server  Application
# 2     FXO_BR_US_BusinessReadiness                Computer  Application
# 3                           Other                 Scanner  Application
# 4                           Other                  Server  Application
# 5                           Other                Database  Application
# 6                           Other                Computer  Application
# 7                           Other                Computer  Application
# 8       FXS_SDESK_GLB_ProblemMgmt                Computer  Application
# 9                           Other                   Other  Application
# 10                          Other                Computer  Application
# 11          FSC_L3WMSSTERLINGLOFT                Computer  Application
# 12      FXO_SDESK_GLB_ProblemMgmt                Computer  Application
# 13    FXO_BR_US_BusinessReadiness                Computer  Application
# 14                          Other                   Other  Application
# 15      FXO_SDESK_GLB_ProblemMgmt                Computer  Application
# 16                          Other                  Server  Application
# 17          FSC_L3WMSSTERLINGLOFT                Computer  Application
# 18          FSC_L3WMSSTERLINGLOFT                Computer  Application
# 19      FXO_SDESK_GLB_ProblemMgmt                   Other  Application
# 20      FXO_SDESK_GLB_ProblemMgmt                Computer  Application
# 21                          Other                  Server  Application
# 22      FXO_SDESK_GLB_ProblemMgmt                Computer  Application
# 23      FXO_SDESK_GLB_ProblemMgmt                Computer  Application
# 24                          Other  'Communication Device'  Application
# 25      FXO_SDESK_GLB_ProblemMgmt                Computer  Application
# 26                          Other                   Other  Application
# 27               FSC_ITL3O2STIBCO                Computer  Application
# 28                          Other                Database  Application
# 29                          Other                  Server  Application
# ...                           ...                     ...          ...
# 1004                        Other                 Network     Hardware
# 1005                        Other                Computer     Hardware
# 1006                        Other                 Network     Hardware
# 1007                        Other                  Server     Hardware
# 1008                        Other                  Server     Hardware
# 1009      FXS_EIS_GLB_ProblemMgmt                Computer     Hardware
# 1010    FXO_SDESK_GLB_ProblemMgmt                Computer     Hardware
# 1011                        Other  'Communication Device'     Hardware
# 1012                        Other                 Scanner     Hardware
# 1013    FXO_SDESK_GLB_ProblemMgmt                 Scanner     Hardware
# 1014                        Other                Database     Hardware
# 1015                        Other                 Network     Hardware
# 1016                        Other                Computer     Hardware
# 1017    FXO_SDESK_GLB_ProblemMgmt                   Other     Hardware
# 1018    FXO_SDESK_GLB_ProblemMgmt                Computer     Hardware
# 1019    FXO_SDESK_GLB_ProblemMgmt                Computer     Hardware
# 1020                        Other                  Server     Hardware
# 1021    FXO_SDESK_GLB_ProblemMgmt                Computer     Hardware
# 1022    FXO_SDESK_GLB_ProblemMgmt                Computer     Hardware
# 1023      FXS_EIS_GLB_ProblemMgmt                 Network     Hardware
# 1024      FXS_EIS_GLB_ProblemMgmt                  Server     Hardware
# 1025                        Other                  Server     Hardware
# 1026                        Other                Database     Hardware
# 1027      FXS_EIS_GLB_ProblemMgmt                  Server     Hardware
# 1028      FXS_EIS_GLB_ProblemMgmt                 Scanner     Hardware
# 1029                        Other                  Server     Hardware
# 1030       FXS_WASDRATINGTRACKING                  Server     Hardware
# 1031                        Other                 Scanner     Hardware
# 1032      FXS_EIS_GLB_ProblemMgmt                 Network     Hardware
# 1033      FXS_EIS_GLB_ProblemMgmt                  Server     Hardware
#
#                    Company 'Created Time' 'Created by'  'Has Parent'  Impact  \
# 0                    Other      afternoon    ID5069733         False       3
# 1         'FedEx Services'          night        Other          True       2
# 2                    Other      afternoon        Other         False       2
# 3          'FedEx Express'          night    ID5163721          True       2
# 4         'FedEx Services'        evening    ID5305519          True       3
# 5          'FedEx Express'          night    ID5285658          True       3
# 6     'FedEx Freight Inc.'      afternoon     ID973921          True       3
# 7                    Other        morning        Other         False       3
# 8                    Other      afternoon    ID5069733         False       3
# 9         'FedEx Services'      afternoon        Other          True       3
# 10        'FedEx Services'      afternoon    ID5285658          True       3
# 11                   Other      afternoon    ID5069733         False       3
# 12                   Other      afternoon    ID5069733         False       3
# 13                   Other      afternoon        Other         False       2
# 14                   Other          night    ID5163721          True       2
# 15                   Other      afternoon    ID5069733         False       3
# 16        'FedEx Services'      afternoon     ID973921          True       1
# 17                   Other      afternoon    ID5069733         False       2
# 18                   Other      afternoon    ID5069733         False       2
# 19                   Other      afternoon    ID5069733         False       3
# 20                   Other      afternoon        Other         False       3
# 21        'FedEx Services'      afternoon        Other          True       3
# 22                   Other      afternoon    ID5069733         False       3
# 23                   Other      afternoon    ID5069733         False       3
# 24         'FedEx Express'          night        Other          True       3
# 25                   Other      afternoon    ID5069733         False       1
# 26        'FedEx Services'      afternoon        Other          True       3
# 27                   Other      afternoon    ID5069733         False       2
# 28                   Other      afternoon        Other         False       3
# 29        'FedEx Services'      afternoon        Other          True       3
# ...                    ...            ...          ...           ...     ...
# 1004      'FedEx Services'        evening        Other          True       3
# 1005      'FedEx Services'        morning    ID5285658          True       3
# 1006      'FedEx Services'        morning    ID5163721          True       3
# 1007       'FedEx Express'        morning    ID5285658          True       3
# 1008      'FedEx Services'        morning     ID973921          True       3
# 1009       'FedEx Express'          night    ID5163721          True       3
# 1010                 Other      afternoon    ID5069733         False       3
# 1011        'FedEx Ground'        morning        Other          True       3
# 1012        'FedEx Ground'        morning     ID973921          True       3
# 1013                 Other      afternoon        Other         False       2
# 1014      'FedEx Services'        morning    ID5285658          True       3
# 1015      'FedEx Services'        morning     ID836059          True       1
# 1016      'FedEx Services'      afternoon     ID973921          True       2
# 1017                 Other        morning        Other         False       3
# 1018                 Other      afternoon    ID5069733         False       3
# 1019                 Other      afternoon    ID5069733         False       3
# 1020      'FedEx Services'        morning        Other          True       2
# 1021                 Other      afternoon    ID5069733         False       3
# 1022                 Other      afternoon    ID5069733         False       3
# 1023      'FedEx Services'        evening    ID3667964          True       3
# 1024      'FedEx Services'        morning        Other          True       3
# 1025      'FedEx Services'      afternoon     ID847287          True       3
# 1026        'FedEx Ground'      afternoon     ID847287          True       3
# 1027      'FedEx Services'      afternoon    ID3667964          True       2
# 1028        'FedEx Ground'        morning     ID973921          True       3
# 1029      'FedEx Services'      afternoon    ID5285658          True       2
# 1030      'FedEx Services'      afternoon     ID836059          True       3
# 1031        'FedEx Ground'        morning        Other          True       3
# 1032         'TNT Express'        morning     ID847287          True       3
# 1033      'FedEx Services'      afternoon     ID973921          True       3
#
#       'Major Problem'            'Opened by'  Priority      Type  Urgency  \
# 0               False   'Admin-Arturo Reyes'         5  Standard        3
# 1                True         'Nivedita Roy'         4      ITCC        3
# 2               False  'Matthew Gonderinger'         3  Standard        2
# 3                True     'Divakar Durgapal'         3      ITCC        2
# 4                True         'Ashish Bisht'         5      ITCC        3
# 5                True          'Shafi Ahmed'         4      ITCC        2
# 6                True        'Stephen Barch'         4      ITCC        2
# 7                True                  Other         5      ITCC        3
# 8               False   'Admin-Arturo Reyes'         5  Standard        3
# 9                True    'Marconius Donahue'         5      ITCC        3
# 10               True          'Shafi Ahmed'         5      ITCC        3
# 11              False   'Admin-Arturo Reyes'         5  Standard        3
# 12              False   'Admin-Arturo Reyes'         5  Standard        3
# 13              False  'Matthew Gonderinger'         3  Standard        2
# 14               True     'Divakar Durgapal'         3      ITCC        2
# 15              False   'Admin-Arturo Reyes'         5  Standard        3
# 16               True        'Stephen Barch'         2      ITCC        2
# 17              False   'Admin-Arturo Reyes'         2  Standard        1
# 18              False   'Admin-Arturo Reyes'         4      ITCC        3
# 19              False   'Admin-Arturo Reyes'         4  Standard        2
# 20              False                  Other         5  Standard        3
# 21               True           'Brad Moore'         5      ITCC        3
# 22              False   'Admin-Arturo Reyes'         5  Standard        3
# 23              False   'Admin-Arturo Reyes'         5  Standard        3
# 24               True          'David Light'         4      ITCC        2
# 25              False   'Admin-Arturo Reyes'         2  Standard        2
# 26               True    'Marconius Donahue'         5      ITCC        3
# 27              False   'Admin-Arturo Reyes'         3  Standard        2
# 28              False        'Michael Olton'         5  Standard        3
# 29               True           'Brad Moore'         5      ITCC        3
# ...               ...                    ...       ...       ...      ...
# 1004             True           'Sean Green'         5      ITCC        3
# 1005             True          'Shafi Ahmed'         5  Standard        3
# 1006             True     'Divakar Durgapal'         5      ITCC        3
# 1007             True          'Shafi Ahmed'         4  Standard        2
# 1008             True        'Stephen Barch'         5      ITCC        3
# 1009             True     'Divakar Durgapal'         5      ITCC        3
# 1010            False   'Admin-Arturo Reyes'         5  Standard        3
# 1011             True    'Sandrina Khongjee'         5      ITCC        3
# 1012             True        'Stephen Barch'         5      ITCC        3
# 1013            False  'Matthew Gonderinger'         3  Standard        2
# 1014             True          'Shafi Ahmed'         5      ITCC        3
# 1015             True      'Khouri Mitchell'         3      ITCC        3
# 1016             True        'Stephen Barch'         4      ITCC        3
# 1017            False           'Greg Malek'         5  Standard        3
# 1018            False   'Admin-Arturo Reyes'         5  Standard        3
# 1019            False   'Admin-Arturo Reyes'         5  Standard        3
# 1020             True          'David Light'         2      ITCC        1
# 1021            False   'Admin-Arturo Reyes'         5  Standard        3
# 1022            False   'Admin-Arturo Reyes'         5  Standard        3
# 1023             True        'DZundra Green'         5      ITCC        3
# 1024             True         'Nivedita Roy'         5      ITCC        3
# 1025             True        'Logan Simmons'         5      ITCC        3
# 1026             True        'Logan Simmons'         5      ITCC        3
# 1027             True        'DZundra Green'         2      ITCC        1
# 1028             True        'Stephen Barch'         5      ITCC        3
# 1029             True          'Shafi Ahmed'         4  Standard        3
# 1030             True      'Khouri Mitchell'         5      ITCC        3
# 1031            False                  Other         5  Standard        3
# 1032             True        'Logan Simmons'         5      ITCC        3
# 1033             True        'Stephen Barch'         5      ITCC        3
#
#           pca1      pca2      pca3      pca4
# 0    -2.269490 -0.117509 -0.305814  0.073808
# 1     1.532381 -0.049464  0.305104 -0.272206
# 2    -0.715852  1.894260  0.977335  0.417765
# 3     1.566688  1.199983  0.062017  0.866049
# 4     1.102603 -1.132164 -0.515550 -0.770342
# 5     1.141185  0.039522  0.183093  0.499074
# 6     0.615911  0.207839 -0.659730  0.049773
# 7    -0.116427 -0.914886  0.963604 -0.083307
# 8    -2.098339 -0.172467 -0.258812  0.028975
# 9     0.644104 -1.027654 -0.040438 -0.484514
# 10    0.433169 -0.957445 -0.691865 -0.184237
# 11   -2.097307 -0.153592 -0.247704  0.041269
# 12   -2.269490 -0.117509 -0.305814  0.073808
# 13   -0.715852  1.894260  0.977335  0.417765
# 14    1.201728  1.338400  0.182114  0.655430
# 15   -2.269490 -0.117509 -0.305814  0.073808
# 16    2.000611  2.381751 -0.637852 -0.620910
# 17   -0.934791  3.296335 -0.000659  0.309659
# 18   -1.177251  0.856703 -0.695366  0.204866
# 19   -1.671119  0.986372 -0.056720 -0.064709
# 20   -1.674245 -0.399782  0.789637  0.227122
# 21    0.846419 -1.074130 -0.191572 -0.839771
# 22   -2.269490 -0.117509 -0.305814  0.073808
# 23   -2.269490 -0.117509 -0.305814  0.073808
# 24    1.174574  0.005556  0.600523  0.500958
# 25   -1.121650  3.331774 -0.057734  0.346791
# 26    0.644104 -1.027654 -0.040438 -0.484514
# 27   -1.337886  2.141166 -0.071883  0.221679
# 28   -1.094270 -0.538212  1.094186 -0.609018
# 29    0.846419 -1.074130 -0.191572 -0.839771
# ...        ...       ...       ...       ...
# 1004  0.946672 -1.148664  0.220011 -0.414632
# 1005  0.217019 -1.022440  0.545924 -0.112252
# 1006  1.013946 -1.234372  0.002195 -0.037374
# 1007  0.810188  0.064487  0.766658 -0.202507
# 1008  1.178954 -1.271779 -0.178845 -0.750837
# 1009  0.462767 -1.116056 -0.507510  1.913983
# 1010 -2.269490 -0.117509 -0.305814  0.073808
# 1011  0.764110 -1.251888  0.845176  0.044659
# 1012  0.777621 -1.219075  0.194191 -0.086752
# 1013 -0.683067  1.881682  1.054236  0.219239
# 1014  0.959893 -1.223652  0.255391 -0.269926
# 1015  1.709473  1.085027  0.210441 -0.143640
# 1016  0.829967  0.168780 -0.801263 -0.241349
# 1017 -1.138730 -0.651579  1.566621  0.165687
# 1018 -2.269490 -0.117509 -0.305814  0.073808
# 1019 -2.269490 -0.117509 -0.305814  0.073808
# 1020  2.331728  2.178590  0.769464 -0.368843
# 1021 -2.269490 -0.117509 -0.305814  0.073808
# 1022 -2.269490 -0.117509 -0.305814  0.073808
# 1023  0.860826 -1.149338 -0.706328  0.572982
# 1024  1.048006 -1.349735  0.290413  0.336284
# 1025  0.813002 -1.047416 -0.779699 -0.899682
# 1026  0.396412 -1.011732 -0.344663 -0.236201
# 1027  1.912311  2.382531 -0.889516  0.427493
# 1028  0.659615 -1.280319 -0.032126  0.913498
# 1029  0.669082  0.244589 -0.079757 -0.722802
# 1030  0.630783 -1.003535 -0.903029 -0.194612
# 1031 -0.114954 -0.985597  1.677658 -0.180643
# 1032  0.605716 -1.252594 -0.024846  0.790872
# 1033  0.734765 -1.128775 -1.112250  0.106357
#
# [1034 rows x 17 columns]
