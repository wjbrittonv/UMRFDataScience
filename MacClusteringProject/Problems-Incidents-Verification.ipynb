# %%
import pandas as pd

# %% [markdown]
# ### Checks to make sure all problem numbers in incidents dataset are in the problems dataset and find which problem numbers in problems dataset are not in incidents dataset

# %%
incidents = pd.read_excel('./datasets/incidents_2019-03-21.xlsx')
problems = pd.read_excel('./datasets/problems_2019-03-21.xlsx')

# %%
incidents.head()
# Out:
#          Number     Problem Affected Company      Business service  \
# 0  INC010068680  PRB0060003    FedEx Express  Communication Device
# 1  INC010000197  PRB0060003    FedEx Express  Communication Device
# 2  INC010003952  PRB0060019   FedEx Services               Scanner
# 3  INC010269074  PRB0060026   FedEx Services              Database
# 4  INC010269078  PRB0060026   FedEx Services              Database
#
#    ALERTING (MIN)  Awareness (Min)  Acknowledge (Min)              Opened  \
# 0             NaN              NaN                NaN 2018-06-17 03:59:28
# 1             0.0             66.0               66.0 2018-06-17 03:59:28
# 2             0.0              1.0                1.0 2018-06-18 08:24:50
# 3             NaN              NaN                NaN 2018-06-18 15:40:15
# 4             NaN              NaN                NaN 2018-06-18 15:40:15
#
#               Created              Closed       ...       User Location  \
# ...

# %%
problems.head()
# Out:
#      Problem Manager      Number  Active  Activity due  \
# 0       Naveen Kumar  PRB0062159    True           NaN
# 1        Mark Duncan  PRB0060146   False           NaN
# 2       Naveen Kumar  PRB0060758   False           NaN
# 3  Christophe Gurley  PRB0060985   False           NaN
# 4   Michael Kennemer  PRB0060147   False           NaN
#
#    Additional assignee list           Approval  Approval history  \
# 0                       NaN  Not Yet Requested               NaN
# 1                       NaN  Not Yet Requested               NaN
# 2                       NaN  Not Yet Requested               NaN
# 3                       NaN  Not Yet Requested               NaN
# 4                       NaN  Not Yet Requested               NaN
#
#    Approval set    Assigned to          Assignment group ...   \
# 0           NaN            NaN          FSC_ITL3O2STIBCO ...
# 1           NaN          V Sox  FXF_SPT_US_FIELDLINEHAUL ...
# ...

# %%
incidents[~incidents['Problem'].isin(problems['Number'])]
# Out:
# Empty DataFrame
# ...

# %%
problems[~problems['Number'].isin(incidents['Problem'])]
# Out:
#          Problem Manager      Number  Active  Activity due  \
# 865                  NaN  PRB0061051   False           NaN
# 866         Daniel Smith  PRB0060945    True           NaN
# 867         Daniel Smith  PRB0060968    True           NaN
# 868         Daniel Smith  PRB0060925    True           NaN
# 869         Daniel Smith  PRB0060965    True           NaN
# 870         Daniel Smith  PRB0060960    True           NaN
# 871         Daniel Smith  PRB0060924    True           NaN
# 872         Daniel Smith  PRB0060967    True           NaN
# 873           Dawn Gallo  PRB0060752    True           NaN
# 874         Daniel Smith  PRB0060877    True           NaN
# 875         Daniel Smith  PRB0060855    True           NaN
# 876         Daniel Smith  PRB0060947    True           NaN
# 877         Daniel Smith  PRB0060959    True           NaN
# 878         Daniel Smith  PRB0060962    True           NaN
# 879         Daniel Smith  PRB0060946    True           NaN
# ...
