# %%
import pandas as pd

# %%
incidents = pd.read_excel('incidents_with_problems.xlsx')
problems = pd.read_csv('problem_pdsm_simpleclean.csv')

# %%
problems
# Out:
#      Number  Priority      Business service        Category  \
# 0     63212         5                Server        Hardware
# 1     63210         5              Computer        Hardware
# 2     63205         5                Switch         Network
# 3     63204         5                Server        Hardware
# 4     63201         5                Switch         Network
# 5     63200         3              Computer     Application
# 6     63195         5                Switch         Network
# 7     63194         3                Switch         Network
# 8     63187         2              Computer        Hardware
# 9     63173         5               Scanner        Hardware
# 10    63158         5              Computer        Hardware
# 11    63147         5                Server     Application
# 12    63146         5                 Other         Network
# 13    63145         3                Server        Hardware
# 14    63144         5               Scanner     Application
# 15    63143         5                 Other         Network
# 16    63142         3                 Other         Network
# 17    63141         4               Storage        Hardware
# 18    63140         5                Switch         Network
# 19    63139         5  Communication Device         Network
# 20    63132         3                 Other         Network
# 21    63125         3                Server     Application
# 22    63124         5                Server     Application
# 23    63121         5              Database        Hardware
# 24    63117         5               Scanner        Hardware
# 25    63113         3               Scanner        Hardware
# 26    63107         5                 Other     Application
# 27    63106         5                 Other     Application
# 28    63105         2                Server     Application
# 29    63104         5                Server     Application
# ..      ...       ...                   ...             ...
# 767   60136         5                Server     Application
# 768   60135         5                Server     Application
# 769   60123         5                Server     Application
# 770   60121         5               Network     Application
# 771   60120         5                Server        Hardware
# 772   60117         4                Server     Application
# 773   60116         5               Network        Hardware
# 774   60087         3               Network     Application
# 775   60086         5                Server     Application
# 776   60085         5               Network        Hardware
# 777   60084         5  Communication Device        Hardware
# 778   60083         5  Communication Device        Hardware
# 779   60075         5  Communication Device  Inquiry / Help
# 780   60064         5              Computer     Application
# 781   60054         5                Server     Application
# 782   60053         5              Database     Application
# 783   60050         5              Database     Application
# 784   60048         2               Network     Application
# 785   60045         5              Computer     Application
# 786   60044         5                Server     Application
# 787   60042         5              Computer     Application
# 788   60041         5               Network     Application
# 789   60040         3                Server     Application
# 790   60038         5  Communication Device     Application
# 791   60037         4               Network        Hardware
# 792   60030         5              Database     Application
# 793   60029         5              Database     Application
# 794   60026         5              Database     Application
# 795   60019         5               Scanner        Hardware
# 796   60003         5  Communication Device        Hardware
#
#                 Company              Created Created Time  Created by  Impact  \
# 0        FedEx Services  2019-02-13 08:47:23      morning     5163721       3
# 1        FedEx Services  2019-02-13 06:51:16      morning     5163721       3
# 2        FedEx Services  2019-02-12 22:00:36        night     3667964       3
# 3        FedEx Services  2019-02-12 21:03:05        night      836059       3
# 4          FedEx Ground  2019-02-12 07:58:23      morning     5163721       3
# 5         FedEx Express  2019-02-12 06:07:53      morning     5163721       2
# 6    FedEx Freight Inc.  2019-02-12 04:42:01        night     5163721       3
# 7          FedEx Ground  2019-02-12 03:16:19        night     3667964       3
# 8         FedEx Express  2019-02-11 22:03:47        night     5305519       2
# 9          FedEx Ground  2019-02-11 14:23:59    afternoon      973921       3
# 10   FedEx Freight Inc.  2019-02-11 04:49:45        night     5163721       3
# 11      TNT Express-422  2019-02-10 15:03:15    afternoon     3699687       3
# 12         FedEx Ground  2019-02-09 16:37:16    afternoon      973921       3
# 13       FedEx Services  2019-02-09 14:19:35    afternoon      973921       2
# 14         FedEx Ground  2019-02-09 13:33:53    afternoon      973921       3
# 15         FedEx Ground  2019-02-09 08:55:36      morning     3732283       3
# 16         FedEx Ground  2019-02-09 04:58:12        night     3667964       3
# 17       FedEx Services  2019-02-09 01:56:01        night     3667964       3
# 18         FedEx Ground  2019-02-08 12:03:47    afternoon     3659760       3
# 19   FedEx Freight Inc.  2019-02-08 11:45:55      morning     5285658       3
# 20       FedEx Services  2019-02-08 03:41:06        night     3667964       3
# 21       FedEx Services  2019-02-07 22:19:53        night     3667964       2
# 22       FedEx Services  2019-02-07 21:59:24        night     3692199       3
# 23       FedEx Services  2019-02-07 20:40:03      evening     3659168       3
# 24         FedEx Ground  2019-02-07 17:38:06      evening     3624748       3
# 25        FedEx Express  2019-02-07 08:25:43      morning     5285658       2
# 26         FedEx Ground  2019-02-06 19:31:22      evening      622891       3
# 27         FedEx Ground  2019-02-06 17:20:53      evening     3699687       3
# 28       FedEx Services  2019-02-06 16:50:56    afternoon      847287       1
# 29       FedEx Services  2019-02-06 14:43:09    afternoon      205028       3
# ..                  ...                  ...          ...         ...     ...
# 767      FedEx Services  2018-06-27 19:43:50      evening     5305519       3
# 768      FedEx Services  2018-06-27 19:31:48      evening     5305519       3
# 769      FedEx Services  2018-06-27 12:12:15    afternoon      847287       3
# 770      FedEx Services  2018-06-27 01:39:02        night     3659168       3
# 771      FedEx Services  2018-06-26 20:22:42      evening     5305519       3
# 772      FedEx Services  2018-06-26 16:35:19    afternoon      847287       3
# 773     TNT Express-422  2018-06-26 16:15:33    afternoon      847287       3
# 774      FedEx Services  2018-06-23 20:29:44      evening     3667964       2
# 775      FedEx Services  2018-06-23 15:34:01    afternoon      847287       3
# 776      FedEx Services  2018-06-23 01:02:22        night      828618       3
# 777      FedEx Services  2018-06-21 21:08:48        night      828618       3
# 778      FedEx Services  2018-06-21 20:50:04      evening      828618       3
# 779               Other  2018-06-21 13:49:43    afternoon      847287       3
# 780      FedEx Services  2018-06-20 23:55:25        night     3667964       3
# 781      FedEx Services  2018-06-20 16:37:14    afternoon      836059       3
# 782      FedEx Services  2018-06-20 13:48:11    afternoon      483039       3
# 783      FedEx Services  2018-06-20 13:30:59    afternoon      483039       3
# 784      FedEx Services  2018-06-20 11:57:09      morning      483039       2
# 785      FedEx Services  2018-06-19 23:30:48        night     3667964       3
# 786      FedEx Services  2018-06-19 23:01:15        night     3667964       3
# 787      FedEx Services  2018-06-19 18:44:53      evening      847287       3
# 788      FedEx Services  2018-06-19 18:38:51      evening      847287       3
# 789      FedEx Services  2018-06-19 18:16:22      evening      836059       2
# 790      FedEx Services  2018-06-19 16:34:51    afternoon      847287       3
# 791      FedEx Services  2018-06-19 15:37:07    afternoon      847287       3
# 792        FedEx Ground  2018-06-19 14:02:09    afternoon      395016       3
# 793        FedEx Ground  2018-06-19 13:50:59    afternoon      395016       3
# 794      FedEx Services  2018-06-18 21:36:54        night     5305519       3
# 795      FedEx Services  2018-06-18 15:57:14    afternoon      483039       3
# 796       FedEx Express  2018-06-18 08:04:44      morning      572652       3
#
#      Major Problem     Problem Manager  Related Incidents      Type  Urgency  \
# 0             True  Christopher Barber                  1      ITCC        3
# 1             True               Other                  1      ITCC        3
# 2             True  Christopher Barber                  1      ITCC        3
# 3             True  Christopher Barber                  1      ITCC        3
# 4             True           Eli Smith                  1      ITCC        3
# 5             True      Terri Hamilton                  1      ITCC        2
# 6             True           Eli Smith                  1      ITCC        3
# 7             True           Eli Smith                  1      ITCC        1
# 8             True  Christopher Barber                  1      ITCC        1
# 9             True  Christopher Barber                  1      ITCC        3
# 10            True  Christopher Barber                  1      ITCC        3
# 11            True          Brad Moore                  0      ITCC        3
# 12            True           Eli Smith                  1      ITCC        3
# 13            True    Christina Hanlin                  1      ITCC        2
# 14            True           Eli Smith                  1      ITCC        3
# 15            True           Eli Smith                  1      ITCC        3
# 16            True           Eli Smith                  1      ITCC        1
# 17            True  Christopher Barber                  1      ITCC        2
# 18            True  Christopher Barber                  1      ITCC        3
# 19            True    Christina Hanlin                  1      ITCC        3
# 20            True  Christopher Barber                  1      ITCC        1
# 21            True           Eli Smith                  1      ITCC        2
# 22            True     LaToya Williams                  1      ITCC        3
# 23            True  Christopher Barber                  1      ITCC        3
# 24           False               Other                  1  Standard        3
# 25            True  Christopher Barber                  1      ITCC        2
# 26            True               Other                  1      ITCC        3
# 27            True  Christopher Barber                  1      ITCC        3
# 28            True    Christina Hanlin                  1      ITCC        2
# 29            True   Christophe Gurley                  0      ITCC        3
# ..             ...                 ...                ...       ...      ...
# 767           True     Randall Painter                  1  Standard        3
# 768           True               Other                  1  Standard        3
# 769           True    Christina Hanlin                  1      ITCC        3
# 770           True   Christophe Gurley                  1  Standard        3
# 771           True           Eli Smith                  1  Standard        3
# 772           True      Terri Hamilton                  1      ITCC        2
# 773           True               Other                  0      ITCC        3
# 774           True           Eli Smith                  0  Standard        2
# 775           True    Christina Hanlin                  1      ITCC        3
# 776           True          Brad Moore                  1      ITCC        3
# 777           True               Other                  1      ITCC        3
# 778           True               Other                  0      ITCC        3
# 779           True      Terri Hamilton                  3      ITCC        3
# 780           True   Christophe Gurley                  1      ITCC        3
# 781           True   Christophe Gurley                  1      ITCC        3
# 782           True    Michael Kennemer                  1      ITCC        3
# 783           True     Randall Painter                  1      ITCC        3
# 784           True           Eli Smith                  1      ITCC        1
# 785          False      D'Zundra Green                  1  Standard        3
# 786          False      D'Zundra Green                  1  Standard        3
# 787           True           Eli Smith                  1      ITCC        3
# 788           True   Christophe Gurley                  1      ITCC        3
# 789           True  Christopher Barber                  1      ITCC        2
# 790           True    Michael Kennemer                  1      ITCC        3
# 791           True     Randall Painter                  1      ITCC        2
# 792          False       Stephen Wolff                  1  Standard        3
# 793          False       Stephen Wolff                  1  Standard        3
# 794          False         Mark Duncan                  1      ITCC        3
# 795           True   Christophe Gurley                  1      ITCC        3
# 796          False           Eli Smith                  1      ITCC        3
#
#                                      Short description  \
# 0    CANCELLED - Lync issue that cleared with no kn...
# 1    Ground locations are no longer reporting issue...
# 2                     CANCELLED - local power outage .
# 3    CANCELLED - issue cleared following a DB proce...
# 4                         Cancelled -Local power issue
# 5    Multiple FXE locations experienced slow respon...
# 6                         Cancelled -Local power issue
# 7                         Cancelled -Local power issue
# 8                                CANCELLED - TNT issue
# 9                       CANCELLED - single site issue
# 10                       CANCELLED - single site issue
# 11                              CANCELLED - TNT issue
# 12        Cancelled-local power outage sort completed
# 13   Some FedEx and Vendor (GCServices) reps are ex...
# 14    Some FedEx Ground stations were unable to acc...
# 15                        Cancelled-local power outage
# 16   Cancelled-Local power outage  was the root cause.
# 17   CANCELLED - other SAN paths available for full...
# 18   [from ITCC] CANCELLED - one location FXG site ...
# 19   Some Freight users experienced issues with Doc...
# 20   [from ITCC] CANCELLED - on location FXG Hub Si...
# 21   Fedex.com/WSGW/OneSource/Retail clients may ha...
# 22   Some internal users are not able to locate rev...
# 23   CANCELLED - issue cleared after job completed ...
# 24                        FXG - Panasonic hazmat error
# 25   Some users In the Memphis hub on the 1st, 3rd,...
# 26           Master: mc 55 having loading eform  issue
# 27   CANCELLED - reporting was delayed but all back...
# 28   Freight customers may have experienced issues ...
# 29   INCs have been linked to prb62412Clients may h...
# ..                                                 ...
# 767  Consolidate Data Entry sites are experiencing ...
# 768  Enterprise Service Desk reported that 8 Ground...
# 769  Freight International Services in Uniontown, O...
# 770  Back end systems responsible for processing ec...
# 771  Some internal Fedex ground users experienced s...
# 772  The Pilot Bonus System experienced issues due ...
# 773  [cancelling. was reopened by the system after ...
# 774  Multiple users in Service Desk and Offshore ag...
# 775         FXO/FXE users saw errors with Taxware/WOSV
# 776  Issues with VDI as well as rating, tracking, a...
# 777  Users are the GOC and CAC are not able to reco...
# 778  Users are the GOC and CAC are not able to reco...
# 779  FXO - Multiple centers experienced problems re...
# 780  FXG 0432 Columbus, OH site experienced issues ...
# 781  CRSV(Common Rate Services) may have experience...
# 782  FedExNet Weblogic servers experienced connecti...
# 783  FedEx.com, Rating applications, and Webservice...
# 784  Multiple Flight Planning Systems applications ...
# 785  Some SD users experienced connectivity issues ...
# 786  Multiple users in SD and Offshore agents  expe...
# 787  Multiple users  experienced intermittent conne...
# 788   Ground station SHPT 0711 experienced network ...
# 789  Users experienced connection failures due to a...
# 790  The Chat application in the self service porta...
# 791  The Pittsburg call center was experiencing iss...
# 792  Commercial invoice images not populating in Fe...
# 793  Critical //prh01369 //Automic_Scheduler //Auto...
# 794  Due to an Oracle Database node failure, multip...
# 795  Multiple locations reporting user login issues...
# 796  Users at the MOC and GOC  experienced issues w...
#
#                                               Keywords  Has Parent
# 0    ['short duration', 'lync issue', 'know interve...        True
# 1    ['longer reporting issues seeing vsa records w...        True
# 2                               ['local power outage']        True
# 3    ['issue cleared following', 'db process comple...        True
# 4                                ['local power issue']        True
# 5    ['ground delivery routes ).', 'hung roads gdr'...        True
# 6                                ['local power issue']        True
# 7                                ['local power issue']        True
# 8                                        ['tnt issue']        True
# 9                                ['single site issue']        True
# 10                               ['single site issue']        True
# 11                                       ['tnt issue']        True
# 12               ['local power outage sort completed']        True
# 13   ['experiencing intermittent issues', 'tracking...        True
# 14   ['flex applications due', 'fedex ground statio...        True
# 15                              ['local power outage']        True
# 16                ['local power outage', 'root cause']        True
# 17          ['san paths available', 'full redundancy']        True
# 18   ['one location fxg site 495', 'local utility p...        True
# 19   ['freight users experienced issues', 'yard app...        True
# 20   ['location fxg hub site 923', 'experienced net...        True
# 21   ['processing credit card transactions due', 'r...        True
# 22   ['transaction operational data source', 'locat...        True
# 23   ['job completed', 'issue cleared', 'engaged ap...        True
# 24                          ['panasonic hazmat error']        True
# 25   ['4th floors experienced intermittent issues w...        True
# 26                    ['loading eform issue', 'mc 55']        True
# 27                   ['support handled appropriately']        True
# 28   ['experienced issues processing freight rating...        True
# 29   ['experienced freight rating impact processing...        True
# ..                                                 ...         ...
# 767  ['consolidate data entry sites', 'genesis appl...        True
# 768  ['experiencing remote system errors', 'enterpr...        True
# 769  ['oh reported documents images', 'weblogic ser...        True
# 770  ['processing ecommerce order mapping', 'back e...        True
# 771  ['internal fedex ground users experienced scan...        True
# 772  ['pilot bonus system experienced issues due', ...        True
# 773           ['000 systems worldwide', 'inc closure']        True
# 774  ['madurai experienced connectivity issues', 'n...        True
# 775                           ['fxe users saw errors']        True
# 776  ['edcw datacenters losing connectivity', 'adre...        True
# 777                                    ['phone calls']        True
# 778                                    ['phone calls']       False
# 779  ['multiple centers experienced problems receiv...        True
# 780  ['dock doors due affected database', 'oh site ...        True
# 781  ['two backend servers', 'common rate services'...        True
# 782  ['fedexnet weblogic servers experienced connec...        True
# 783  ['issue cleared without intervention', 'webser...        True
# 784         ['network infrastructure', 'issue within']        True
# 785  ['sd users experienced connectivity issues wit...        True
# 786  ['offshore agents experienced intermittent con...        True
# 787  ['multiple users experienced intermittent conn...        True
# 788                                                 []        True
# 789  ['users experienced connection failures due', ...        True
# 790        ['self service portal', 'chat application']        True
# 791  ['local telecom provider due', 'pittsburg call...        True
# 792  ['fedex brokerage connection', 'commercial inv...        True
# 793  ['host system prh01369', 'app_set_lnp_ewfcl fa...        True
# 794  ['multiple customer service systems including ...        True
# 795  ['multiple locations reporting user login issu...        True
# 796        ['goc experienced issues', 'turret phones']        True
#
# [797 rows x 17 columns]
